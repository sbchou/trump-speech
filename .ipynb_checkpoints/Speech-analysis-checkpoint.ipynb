# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
import inspect
from datetime import datetime
import seaborn as sns
import glob
from os.path import basename
sns.set_context('poster')

# %%
# Make your word tokenizer. We don't care about punct.
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

# %%
biglist = []

# %%
speeches = glob.glob('data/transcripts/*')
for s in speeches:
    print basename(s)
    with open(s) as speech:
        text = speech.read()
        tokens = tokenizer.tokenize(text)
        biglist.append([basename(s), tokens])
# Out:
# adams-j
# adams-jq
# buchanan
# buren
# bush-g
# bush-gw
# carter
# cleveland
# clinton
# coolidge
# eisenhower
# garfield
# grant
# harding
# harrison-b
# harrison-w
# hayes
# hoover
# jackson
# jefferson
# johnson-lb
# kennedy
# lincoln
# madison
# mckinley
# monroe
# nixon
# obama
# pierce
# polk
# reagan
# roosevelt-fd
# roosevelt-t
# taft
# taylor
# truman
# washington
# wilson

# %%
df = pandas.DataFrame(biglist)
df.columns = ['president', 'tokens']
df.to_csv("data/tokenized-speeches.csv")

# %%
df.head()
len(df)
# Out:
# 38

# %%
df['word_count'] = df['tokens'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#   president                                             tokens  word_count
# 0   adams-j  [When, it, was, first, perceived, in, early, t...        2322
# 1  adams-jq  [In, compliance, with, an, usage, coeval, with...        2917
# 2  buchanan  [Fellow, Citizens, I, appear, before, you, thi...        2836
# 3     buren  [The, practice, of, all, my, predecessors, imp...        3844
# 4    bush-g  [Mr, Chief, Justice, Mr, President, Vice, Pres...        2337

# %%
df.word_count.describe()
# Out:
# count      38.000000
# mean     2709.210526
# std      1514.854772
# min       991.000000
# 25%      1590.750000
# 50%      2374.000000
# 75%      3567.000000
# max      8465.000000
# Name: word_count, dtype: float64

# %%
df.sort_values('word_count', ascending=True)
# Out:
#        president                                             tokens  \
# 32   roosevelt-t  [My, fellow, citizens, no, people, on, earth, ...
# 34        taylor  [Elected, by, the, American, people, to, the, ...
# 18       jackson  [About, to, undertake, the, arduous, duties, t...
# 12         grant  [Citizens, of, the, United, States, Your, suff...
# 23       madison  [Unwilling, to, depart, from, examples, of, th...
# 6         carter  [For, myself, and, for, our, Nation, I, want, ...
# 21       kennedy  [Vice, President, Johnson, Mr, Speaker, Mr, Ch...
# 36    washington  [Fellow, Citizens, of, the, Senate, and, of, t...
# 20    johnson-lb  [My, fellow, countrymen, on, this, occasion, t...
# 5        bush-gw  [President, Clinton, distinguished, guests, an...
# 8        clinton  [My, fellow, citizens, Today, we, celebrate, t...
# 7      cleveland  [Fellow, Citizens, In, the, presence, of, this...
# 37        wilson  [There, has, been, a, change, of, government, ...
# 19     jefferson  [FRIENDS, AND, FELLOW, CITIZENS, Called, upon,...
# 31  roosevelt-fd  [I, am, certain, that, my, fellow, Americans, ...
# 26         nixon  [Senator, Dirksen, Mr, Chief, Justice, Mr, Vic...
# 35        truman  [Mr, Vice, President, Mr, Chief, Justice, and,...
# 0        adams-j  [When, it, was, first, perceived, in, early, t...
# 4         bush-g  [Mr, Chief, Justice, Mr, President, Vice, Pres...
# 27         obama  [My, fellow, citizens, I, stand, here, today, ...
# 10    eisenhower  [My, friends, before, I, begin, the, expressio...
# 16         hayes  [Fellow, Citizens, We, have, assembled, to, re...
# 2       buchanan  [Fellow, Citizens, I, appear, before, you, thi...
# 1       adams-jq  [In, compliance, with, an, usage, coeval, with...
# 11      garfield  [Fellow, Citizens, We, stand, to, day, upon, a...
# 28        pierce  [My, Countrymen, It, a, relief, to, feel, that...
# 13       harding  [My, Countrymen, When, one, surveys, the, worl...
# 25        monroe  [I, should, be, destitute, of, feeling, if, I,...
# 22       lincoln  [In, compliance, with, a, custom, as, old, as,...
# 17        hoover  [My, Countrymen, This, occasion, is, not, alon...
# 3          buren  [The, practice, of, all, my, predecessors, imp...
# 24      mckinley  [Fellow, Citizens, In, obedience, to, the, wil...
# 30        reagan  [Senator, Hatfield, Mr, Chief, Justice, Mr, Pr...
# 9       coolidge  [My, Countrymen, No, one, can, contemplate, cu...
# 14    harrison-b  [Fellow, Citizens, There, is, no, constitution...
# 29          polk  [Fellow, Citizens, Without, solicitation, on, ...
# 33          taft  [My, Fellow, Citizens, Anyone, who, has, taken...
# 15    harrison-w  [Called, from, a, retirement, which, I, had, s...
#
#     word_count
# 32         991
# 34        1091
# 18        1126
# 12        1132
# 23        1181
# 6         1229
# 21        1368
# 36        1431
# 20        1496
# 5         1589
# 8         1596
# 7         1691
# 37        1712
# 19        1732
# 31        1883
# 26        2131
# 35        2284
# 0         2322
# 4         2337
# 27        2411
# 10        2470
# 16        2494
# 2         2836
# 1         2917
# 11        2993
# 28        3342
# 13        3346
# 25        3375
# 22        3631
# 17        3766
# 3         3844
# 24        3977
# 30        4041
# 9         4056
# 14        4407
# 29        4815
# 33        5442
# 15        8465

# %%
df[['president', 'word_count']].to_csv('data/president_word_count.csv')

# %%
df_with_date = pandas.read_csv('data/name-date-wc.csv',index_col=False)

# %%
df_with_date.sort_values('word_count', ascending=False)[:10]
# Out:
#    president  first-term  word_count
# 15  Harrison        1889        8465
# 33      Taft        1909        5442
# 29      Polk        1845        4815
# 14  Harrison        1841        4407
# 9   Coolidge        1925        4056
# 30    Reagan        1981        4041
# 24  McKinley        1897        3977
# 3      Buren        1837        3844
# 17    Hoover        1929        3766
# 22   Lincoln        1861        3631

# %%
df_with_date.sort_values('word_count').plot(x='president',
                                            y='word_count', 
                                            kind='barh',
                                            legend=None)
plt.title('Length of Address')
plt.xlabel('Words') 
plt.ylabel("")
plt.savefig('figs/length-vs-president.png')

# %%
df_with_date.sort_values('first-term', ascending=False).plot(x='president',
                                            y='word_count', 
                                            kind='barh',
                                            legend=None)
plt.title('Length of Address')
plt.xlabel('Words') 
plt.ylabel("")
plt.savefig('figs/length-vs-president.png')

# %% [markdown]
# ## Texty stuff

# %%
## DONT TOKENIZE HERE....
untokenized = []
speeches = glob.glob('data/transcripts/*')
for s in speeches:
    print basename(s)
    with open(s) as speech:
        text = speech.read() 
        untokenized.append([basename(s), text])

raw = pandas.DataFrame(untokenized)
raw.columns = ['president', 'text']
raw.to_csv("data/raw-speeches.csv")
# Out:
# adams-j
# adams-jq
# buchanan
# buren
# bush-g
# bush-gw
# carter
# cleveland
# clinton
# coolidge
# eisenhower
# garfield
# grant
# harding
# harrison-b
# harrison-w
# hayes
# hoover
# jackson
# jefferson
# johnson-lb
# kennedy
# lincoln
# madison
# mckinley
# monroe
# nixon
# obama
# pierce
# polk
# reagan
# roosevelt-fd
# roosevelt-t
# taft
# taylor
# truman
# washington
# wilson

# %%
raw.head()
# Out:
#   president                                               text
# 0   adams-j  When it was first perceived, in early times, t...
# 1  adams-jq  In compliance with an usage coeval with the ex...
# 2  buchanan  Fellow-Citizens:\n\nI appear before you this d...
# 3     buren  The practice of all my predecessors imposes on...
# 4    bush-g  Mr. Chief Justice, Mr. President, Vice Preside...

# %%
from textstat.textstat import textstat

# %%
raw.text.apply(lambda x: textstat.flesch_kincaid_grade(" x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-2fb7b0b559bb> in <module>()
# ----> 1 df.tokens.apply(lambda x: textstat.flesch_kincaid_grade(x))
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2292             else:
#    2293                 values = self.asobject
# -> 2294                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2295
#    2296         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:66124)()
#
# <ipython-input-36-2fb7b0b559bb> in <lambda>(x)
# ----> 1 df.tokens.apply(lambda x: textstat.flesch_kincaid_grade(x))
#
# /usr/local/lib/python2.7/site-packages/textstat/textstat.pyc in flesch_kincaid_grade(self, text)
#     117
#     118     def flesch_kincaid_grade(self, text):
# --> 119         ASL = self.avg_sentence_length(text)
#     120         ASW = self.avg_syllables_per_word(text)
#     121         FKRA = float(0.39 * ASL) + float(11.8 * ASW) - 15.59
#
# /usr/local/lib/python2.7/site-packages/textstat/textstat.pyc in avg_sentence_length(self, text)
#      76     def avg_sentence_length(self, text):
#      77         lc = self.lexicon_count(text)
# ---> 78         sc = self.sentence_count(text)
#      79         try:
#      80             ASL = float(lc/sc)
#
# /usr/local/lib/python2.7/site-packages/textstat/textstat.pyc in sentence_count(self, text)
#      68         """
#      69         ignoreCount = 0
# ---> 70         sentences = re.split(r' *[\.\?!][\'"\)\]]* *', text)
#      71         for sentence in sentences:
#      72             if self.lexicon_count(sentence) <= 2:
#
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/re.pyc in split(pattern, string, maxsplit, flags)
#     169     """Split the source string by the occurrences of the pattern,
#     170     returning a list containing the resulting substrings."""
# --> 171     return _compile(pattern, flags).split(string, maxsplit)
#     172
#     173 def findall(pattern, string, flags=0):
#
# TypeError: expected string or buffer
